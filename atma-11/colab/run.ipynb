# %%
# !nvidia-smi

# %%
class CFG:
  REPO_NAME="competition-solution"
  PYTHON_SCRIPT="exp/exp00_base.py"

  DIR_MOUNT='/content/drive'
  DIR_NAME="atma-11"
  PATH_ENV_GLOBAL="/content/drive/MyDrive/Colab_Notebooks/kaggle-colab/.env_global"
  PATH_ENV_LOCAL="/content/drive/MyDrive/Colab_Notebooks/kaggle-colab/atma11/.env"

  PYTHON_VER="3.8"

# %%
import pathlib
import os 
import logging

# !pip install python-dotenv
# !pip install poetry
from google.colab import drive
from dotenv import load_dotenv

logger=logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)
# Out:
# ...
#      |████████████████████████████████| 175 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 42.1 MB/s
# ...
#      |████████████████████████████████| 424 kB 50.4 MB/s
# ...
#      |████████████████████████████████| 91 kB 10.2 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 40 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.8 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 29.9 MB/s
# ...
#      |████████████████████████████████| 496 kB 28.9 MB/s
# ...
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.8.1
#     Uninstalling importlib-metadata-4.8.1:
#       Successfully uninstalled importlib-metadata-4.8.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.2
#     Uninstalling packaging-21.2:
#       Successfully uninstalled packaging-21.2
# ...

# %%
# mount
drive.mount(CFG.DIR_MOUNT)

# set environment variable
load_dotenv(CFG.PATH_ENV_GLOBAL)

# clone repo
GITHUB_TOKEN=os.environ.get("GITHUB_TOKEN")
USER_NAME=os.environ.get("USER_NAME")
# !git clone https://{GITHUB_TOKEN}@github.com/{USER_NAME}/{CFG.REPO_NAME}.git

# install python
# !sudo apt-get -y update
# !sudo apt-get -y install python{CFG.PYTHON_VER}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Cloning into 'competition-solution'...
# remote: Enumerating objects: 178, done.
# remote: Counting objects: 100% (178/178), done.
# remote: Compressing objects: 100% (95/95), done.
# remote: Total 178 (delta 74), reused 148 (delta 44), pack-reused 0
# Receiving objects: 100% (178/178), 227.96 KiB | 2.02 MiB/s, done.
# Resolving deltas: 100% (74/74), done.
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [73.0 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# ...

# %%
# install package
# %cd {CFG.REPO_NAME}
# !poetry install

# copy env
! cp {CFG.PATH_ENV_LOCAL} {pathlib.Path("/content")/CFG.REPO_NAME/CFG.DIR_NAME}

% cd {CFG.DIR_NAME}
# Out:
# /content/competition-solution
# The currently activated Python version 3.7.12 is not supported by the project (>=3.8,<3.11).
# Trying to find and use a compatible version.
# Using python3.8 (3.8.12)
# Creating virtualenv kaggle-xS7QCl5R-py3.8 in /root/.cache/pypoetry/virtualenvs
# Installing dependencies from lock file
#
# Package operations: 172 installs, 0 updates, 0 removals
#
#   • Installing attrs (21.2.0): Pending...
#   • Installing pyrsistent (0.18.0): Pending...
#   • Installing six (1.16.0): Pending...
#   • Installing traitlets (5.1.1): Pending...
#   • Installing pyrsistent (0.18.0): Pending...
#   • Installing six (1.16.0): Pending...
#   • Installing traitlets (5.1.1): Pending...
#   • Installing attrs (21.2.0): Downloading... 0%
#   • Installing pyrsistent (0.18.0): Pending...
#   • Installing six (1.16.0): Pending...
#   • Installing traitlets (5.1.1): Pending...
#   • Installing pyrsistent (0.18.0): Pending...
#   • Installing six (1.16.0): Pending...
# ...

# %%
# download data
# !mkdir -p {pathlib.Path("/content")/CFG.REPO_NAME/CFG.DIR_NAME/"data"/"raw"} && \
    cd {pathlib.Path("/content")/CFG.REPO_NAME/CFG.DIR_NAME/"data"/"raw"} && \
    wget -O data.zip "https://guruguru-production-public.s3.amazonaws.com/competitions/feeb1beb_3f69_4e40_b989_86f0228112fe/dataset_atmaCup11.zip?AWSAccessKeyId=AKIARC4B4NATPMJHU5HB&Signature=Y8Ar7VcQfu7MKDmCnpEBMUUxpO0%3D&Expires=1636555497" && \
    unzip -n data.zip && \
    mkdir -p photos && \
    unzip -n photos.zip -d ./photos
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: ./photos/835f0f174bf4f212e338.jpg
#   inflating: ./photos/940f3ecc70fb8f8d0631.jpg
#   inflating: ./photos/b6db74aa66a77fd9be15.jpg
#   inflating: ./photos/f7edf2f6f3fe720c30d1.jpg
#   inflating: ./photos/b69de0ac09a239266e2b.jpg
#   inflating: ./photos/9740a0e0e2c8fb531696.jpg
#   inflating: ./photos/e665207010a0b7f1d261.jpg
#   inflating: ./photos/9c1e1f448e3201472b11.jpg
#   inflating: ./photos/f19980ecaa3f40418a76.jpg
#   inflating: ./photos/60ae841e4b9432b47117.jpg
#   inflating: ./photos/85961cae6e88b98ea51b.jpg
#   inflating: ./photos/13a526684ef2328897c1.jpg
#   inflating: ./photos/1690746ecd15d72822ce.jpg
#   inflating: ./photos/d0367122919daab14a5d.jpg
#   inflating: ./photos/637cb6503529108cf804.jpg
#   inflating: ./photos/bfd3e0aa571079b729e8.jpg
#   inflating: ./photos/e45b16a93e6e0ea6f685.jpg
#   inflating: ./photos/515ed11b96c1d4544b96.jpg
#   inflating: ./photos/b784bf741ab68436d6f0.jpg
# ...

# %%
! poetry run python {CFG.PYTHON_SCRIPT}
# Out:
# The currently activated Python version 3.7.12 is not supported by the project (>=3.8,<3.11).
# Trying to find and use a compatible version.
# Using python3.8 (3.8.12)
# Global seed set to 46
# wandb: Currently logged in as: tmdiesel (use `wandb login --relogin` to force relogin)
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 100MB/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# wandb: Tracking run with wandb version 0.12.6
# wandb: Syncing run Fold1
# wandb:  View project at https://wandb.ai/tmdiesel/atma11
# wandb:  View run at https://wandb.ai/tmdiesel/atma11/runs/ajevnecl
# ...
